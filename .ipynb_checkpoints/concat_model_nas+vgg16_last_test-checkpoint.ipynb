# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.utils import to_categorical
from keras.datasets import cifar10
from keras.applications.nasnet import NASNetLarge
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, Input, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D, concatenate, GlobalAveragePooling2D
from keras.models import Sequential, Model
from keras.optimizers import Adamax

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
x_train, x_test = x_train / 255., x_test / 255.
y_train, y_test = to_categorical(y_train, 10), to_categorical(y_test, 10)

# %%
model_nas = NASNetLarge(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
model_nas.trainable = False

# %%
model_vgg = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
model_vgg.trainable = True

# %%
model_nas_out = model_nas.output
model_nas_out = GlobalAveragePooling2D()(model_nas_out)
model_vgg_out = model_vgg.output
model_vgg_out = GlobalAveragePooling2D()(model_vgg_out)
x = concatenate([model_nas_out, model_vgg_out])
x = Dense(10, activation='softmax')(x)

# %%
model = Model(inputs=[model_nas.input, model_vgg.input], outputs=x)
model.compile(optimizer='adamax', loss='binary_crossentropy', metrics=['accuracy'])

# %%
res = model.fit([x_train, x_train], y_train, batch_size=32, epochs=10, validation_data=([x_test, x_test], y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 420s 263ms/step - loss: 0.2169 - accuracy: 0.4775 - val_loss: 0.1453 - val_accuracy: 0.7018
# Epoch 2/10
# 1563/1563 [==============================] - 410s 262ms/step - loss: 0.1147 - accuracy: 0.7692 - val_loss: 0.1147 - val_accuracy: 0.7738
# Epoch 3/10
# 1563/1563 [==============================] - 410s 263ms/step - loss: 0.0845 - accuracy: 0.8331 - val_loss: 0.0937 - val_accuracy: 0.8229
# Epoch 4/10
# 1563/1563 [==============================] - 409s 262ms/step - loss: 0.0628 - accuracy: 0.8778 - val_loss: 0.0871 - val_accuracy: 0.8390
# Epoch 5/10
# 1563/1563 [==============================] - 412s 263ms/step - loss: 0.0468 - accuracy: 0.9115 - val_loss: 0.0960 - val_accuracy: 0.8358
# Epoch 6/10
# 1563/1563 [==============================] - 417s 267ms/step - loss: 0.0342 - accuracy: 0.9355 - val_loss: 0.1032 - val_accuracy: 0.8451
# Epoch 7/10
# 1563/1563 [==============================] - 413s 264ms/step - loss: 0.0261 - accuracy: 0.9528 - val_loss: 0.0944 - val_accuracy: 0.8556
# Epoch 8/10
# 1563/1563 [==============================] - 412s 264ms/step - loss: 0.0197 - accuracy: 0.9662 - val_loss: 0.1084 - val_accuracy: 0.8607
# Epoch 9/10
# 1563/1563 [==============================] - 413s 264ms/step - loss: 0.0145 - accuracy: 0.9754 - val_loss: 0.1192 - val_accuracy: 0.8558
# Epoch 10/10
# 1563/1563 [==============================] - 427s 273ms/step - loss: 0.0126 - accuracy: 0.9786 - val_loss: 0.1221 - val_accuracy: 0.8570

# %%
htr = res.history
loss = htr['loss']
val_loss = htr['val_loss']
accuracy = htr['accuracy']
val_accuracy = htr['val_accuracy']
epochs = range(1, len(accuracy) + 1)

# %%
plt.plot(epochs, loss, label='loss')
plt.plot(epochs, val_loss, label='val_loss')
plt.title('val_loss + loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs, accuracy, label='accuracy')
plt.plot(epochs, val_accuracy, label='val_accuracy')
plt.title('val_accuracy + accuracy')
plt.legend()
plt.show()
